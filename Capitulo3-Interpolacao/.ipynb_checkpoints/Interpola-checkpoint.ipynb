# %% [markdown]
# # Métodos Numéricos e Computacionais Aplicados às Ciências e Engenharias
# ## Capítulo 3 - Interpolação Numérica
# <hr/>

# %% [markdown]
# **Exercício 3.3.1.1**

# %%
import numpy as np
from numpy.polynomial.polynomial import Polynomial
import pylab as plt
from scipy.interpolate import lagrange

x = [2, 2.5, 4]
y = [0.5, 0.4, 0.25]

f = lagrange(x, y)

print(Polynomial(f).coef)

x_new = np.arange(0, 5, 0.1)

fig = plt.figure(figsize = (10,8))
plt.plot(x_new, f(x_new), 'b', x, y, 'ro')
plt.title('Exercício 3.3.1.1 (Lagrange)')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [ 0.05  -0.425  1.15 ]

# %% [markdown]
# **Exercício 3.3.1.2**

# %% [markdown]
# **Lagrange**

# %%
import numpy as np
from numpy.polynomial.polynomial import Polynomial
import pylab as plt
from scipy.interpolate import lagrange

x = [0, 1, 3, 4]
y = [2, 4, 5, 0]

f = lagrange(x, y)

print(Polynomial(f).coef)

x_new = np.arange(0, 5, 0.1)

fig = plt.figure(figsize = (10,8))
plt.plot(x_new, f(x_new), 'b', x, y, 'ro')
plt.title('Exercício 3.3.1.2 (Lagrange)')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [-0.33333333  0.83333333  1.5         2.        ]

# %% [markdown]
# **Newton**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def newton_interpolation(x, y, xi):  
    n = len(x)                                         
    fdd = [[None for x in range(n)] for x in range(n)] 
    yint = [None for x in range(n)]                    
    ea = [None for x in range(n)]                     
    
    for i in range(n):                                
        fdd[i][0] = y[i]
    for j in range(1,n):
        for i in range(n-j):
            fdd[i][j] = (fdd[i+1][j-1] - fdd[i][j-1])/(x[i+j]-x[i])
    
    fdd_table = pd.DataFrame(fdd)                       
    print(fdd_table)
    
    xterm = 1                                           
    yint[0] = fdd[0][0]
    for order in range(1, n):
        xterm = xterm * (xi - x[order-1])
        yint2 = yint[order-1] + fdd[0][order]*xterm
        ea[order-1] = yint2 - yint[order-1]
        yint[order] = yint2
    
    return map(lambda yy, ee : [yy, ee], yint, ea)     

x = [0, 1, 3, 4]
y = [2, 4, 5, 0]

a  = newton_interpolation(x, y, 2)
df = pd.DataFrame(a)
# Out:
#    0    1         2         3
# 0  2  2.0 -0.500000 -0.333333
# 1  4  0.5 -1.833333       NaN
# 2  5 -5.0       NaN       NaN
# 3  0  NaN       NaN       NaN

# %% [markdown]
# **Exercício 3.3.1.3**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def newton_interpolation(x, y, xi):  
    n = len(x)                                         
    fdd = [[None for x in range(n)] for x in range(n)] 
    yint = [None for x in range(n)]                    
    ea = [None for x in range(n)]                     
    
    for i in range(n):                                
        fdd[i][0] = y[i]
    for j in range(1,n):
        for i in range(n-j):
            fdd[i][j] = (fdd[i+1][j-1] - fdd[i][j-1])/(x[i+j]-x[i])
    
    fdd_table = pd.DataFrame(fdd)                       
    print(fdd_table)
    
    xterm = 1                                           
    yint[0] = fdd[0][0]
    for order in range(1, n):
        xterm = xterm * (xi - x[order-1])
        yint2 = yint[order-1] + fdd[0][order]*xterm
        ea[order-1] = yint2 - yint[order-1]
        yint[order] = yint2
    
    return map(lambda yy, ee : [yy, ee], yint, ea)     

x = [-1, 0, 2]
y = [4, 1, -1]

a  = newton_interpolation(x, y, 2)
df = pd.DataFrame(a)
# Out:
#    0    1         2
# 0  4 -3.0  0.666667
# 1  1 -1.0       NaN
# 2 -1  NaN       NaN
